# %%
import numpy as py
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import GaussianNB

# %%
df = pd.read_csv("NB_dataset.csv")

# %%
df.head()
# Out:
#     Age Cabin Embarked     Fare                                          Name  \
# 0  34.5   NaN        Q   7.8292                              Kelly, Mr. James
# 1  47.0   NaN        S   7.0000              Wilkes, Mrs. James (Ellen Needs)
# 2  62.0   NaN        Q   9.6875                     Myles, Mr. Thomas Francis
# 3  27.0   NaN        S   8.6625                              Wirz, Mr. Albert
# 4  22.0   NaN        S  12.2875  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#
#    Parch  PassengerId  Pclass     Sex  SibSp  Survived   Ticket Title  \
# 0      0          892       3    male      0       NaN   330911    Mr
# 1      0          893       3  female      1       NaN   363272   Mrs
# 2      0          894       2    male      0       NaN   240276    Mr
# 3      0          895       3    male      0       NaN   315154    Mr
# 4      1          896       3  female      1       NaN  3101298   Mrs
#
#    Family_Size
# 0            0
# 1            1
# 2            0
# 3            0
# 4            2

# %%
df1 = df[['Age','Survived']]

# %%
df1
# Out:
#       Age  Survived
# 0    34.5       NaN
# 1    47.0       NaN
# 2    62.0       NaN
# 3    27.0       NaN
# 4    22.0       NaN
# ..    ...       ...
# 413  30.0       NaN
# 414  39.0       NaN
# 415  38.5       NaN
# 416  30.0       NaN
# 417   4.0       NaN
#
# [418 rows x 2 columns]

# %%
df1['Survived_new'] = df1['Survived'].map({"NaN": 0, "": 1})
df1.head()
# Out:
# /var/folders/7r/sc_p7h9s61xbb44_rlc_n9_r0000gn/T/ipykernel_17917/904562314.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Survived_new'] = df1['Survived'].map({"NaN": 0, "": 1})
#     Age  Survived  Survived_new
# 0  34.5       NaN           NaN
# 1  47.0       NaN           NaN
# 2  62.0       NaN           NaN
# 3  27.0       NaN           NaN
# 4  22.0       NaN           NaN

# %%
X_train, X_test, y_train, y_test = train_test_split(df1['Age'], df1['Survived'], test_size =0.7 ,random_state=42)

# %%
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 model = GaussianNB()
# ----> 2 model.fit(X_train, y_train)
#
# File ~/Desktop/EDA/.venv/lib/python3.11/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~/Desktop/EDA/.venv/lib/python3.11/site-packages/sklearn/naive_bayes.py:265, in GaussianNB.fit(self, X, y, sample_weight)
#     241 @_fit_context(prefer_skip_nested_validation=True)
#     242 def fit(self, X, y, sample_weight=None):
#     243     """Fit Gaussian Naive Bayes according to X, y.
#     244
#     245     Parameters
#    (...)    263         Returns the instance itself.
#     264     """
# --> 265     y = validate_data(self, y=y)
#     266     return self._partial_fit(
#     267         X, y, np.unique(y), _refit=True, sample_weight=sample_weight
#     268     )
#
# File ~/Desktop/EDA/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2956, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2954     out = check_array(X, input_name="X", **check_params)
#    2955 elif no_val_X and not no_val_y:
# -> 2956     out = _check_y(y, **check_params)
#    2957 else:
#    2958     if validate_separately:
#    2959         # We need this because some estimators validate X and y
#    2960         # separately, and in general, separately calling check_array()
#    2961         # on X and y isn't equivalent to just calling check_X_y()
#    2962         # :(
#
# File ~/Desktop/EDA/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:1407, in _check_y(y, multi_output, y_numeric, estimator)
#    1405     estimator_name = _check_estimator_name(estimator)
#    1406     y = column_or_1d(y, warn=True)
# -> 1407     _assert_all_finite(y, input_name="y", estimator_name=estimator_name)
#    1408     _ensure_no_complex_data(y)
#    1409 if y_numeric and hasattr(y.dtype, "kind") and y.dtype.kind == "O":
#
# File ~/Desktop/EDA/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:120, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     117 if first_pass_isfinite:
#     118     return
# --> 120 _assert_all_finite_element_wise(
#     121     X,
#     122     xp=xp,
#     123     allow_nan=allow_nan,
#     124     msg_dtype=msg_dtype,
#     125     estimator_name=estimator_name,
#     126     input_name=input_name,
#     127 )
#
# File ~/Desktop/EDA/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:169, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     152 if estimator_name and input_name == "X" and has_nan_error:
#     153     # Improve the error message on how to handle missing values in
#     154     # scikit-learn.
#     155     msg_err += (
#     156         f"\n{estimator_name} does not accept missing values"
#     157         " encoded as NaN natively. For supervised learning, you might want"
#    (...)    167         "#estimators-that-handle-nan-values"
#     168     )
# --> 169 raise ValueError(msg_err)
#
# ValueError: Input y contains NaN.
